# %%
import pandas as pd

# %%
df = pd.read_csv("NBA_TRAIN.csv")
df_test = pd.read_csv("NBA_TEST.csv")

# %% [markdown]
# ## 1. 잘하거나 꾸준한 선수 feature 생성

# %%
len(df["shoot player"].unique())
# Out:
# 482

# %%
df.loc[df["current shot outcome"]=="SCORED","CSO"] = 1
df.loc[df["current shot outcome"]=="MISSED","CSO"] = 0

# %%
total = df.groupby("shoot player").sum()
total_score = total["CSO"].sort_values(ascending=False)

# %%
total_score
# Out:
# shoot player
# Russell Westbrook     422.0
# Karl-Anthony Towns    398.0
# Anthony Davis         373.0
# LeBron James          363.0
# Kyrie Irving          356.0
#                       ...
# Brice Johnson           0.0
# Gary Neal               0.0
# Elijah Millsap          0.0
# Aaron Harrison          0.0
# Larry Sanders           0.0
# Name: CSO, Length: 482, dtype: float64

# %%
average = df.groupby("shoot player").mean()
percentage = average["CSO"].sort_values(ascending=False)

# %%
pd.DataFrame(percentage).rename(columns={"CSO": "PERCENT"})
# Out:
#                   PERCENT
# shoot player
# Jarnell Stokes   1.000000
# Walter Tavares   0.750000
# Tyson Chandler   0.701613
# Lucas Nogueira   0.694118
# DeAndre Jordan   0.687023
# ...                   ...
# Mike Tobey       0.000000
# Ben Bentil       0.000000
# Gary Neal        0.000000
# Elijah Millsap   0.000000
# Patricio Garino  0.000000
#
# [482 rows x 1 columns]

# %%
df1 = pd.DataFrame(percentage).rename(columns={"CSO": "PERCENT"}).sort_index()
df2 = pd.DataFrame(total_score).sort_index()
df3 = df1.join(df2)
df4 = df3.sort_values(by="CSO",ascending=False)[:100]
top_players = df4.index[:25]
guaranteed_players = df4[df4["PERCENT"] > 0.5].index
print(len(top_players))
print(len(guaranteed_players))
# Out:
# 25
# 25

# %%
df["self previous shot"].value_counts()
# Out:
# MISSED    56595
# SCORED    47240
# Name: self previous shot, dtype: int64

# %% [markdown]
# ## 2. 포지션 One-hot 인코딩으로 변경

# %%
df = pd.read_csv("NBA_TRAIN.csv")
df_test = pd.read_csv("NBA_TEST.csv")




from sklearn.preprocessing import OneHotEncoder
onehotencoder1 = OneHotEncoder()
X = onehotencoder1.fit_transform(df[["player position"]]).toarray()
positions =  pd.DataFrame(X,columns=onehotencoder1.categories_)
df = pd.concat([df, positions], axis=1)
X = onehotencoder1.transform(df_test[["player position"]]).toarray()
positions = pd.DataFrame(X,columns=onehotencoder1.categories_)

# %% [markdown]
# ## 3. 슛타입 정리

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df["shot type"].value_counts())
# Out:
# Jump Shot                                    47020
# Layup                                         7939
# Pullup Jump Shot                              7369
# Driving Layup                                 6682
# Floating Jump Shot                            2274
# Step Back Jump Shot                           2263
# Hook Shot                                     2085
# Tip Layup Shot                                2029
# Cutting Layup Shot                            1928
# Running Layup                                 1825
# Turnaround Jump Shot                          1621
# Driving Floating Jump Shot                    1591
# Dunk                                          1385
# Fadeaway Jumper                               1367
# Putback Layup                                 1132
# Driving Finger Roll Layup                     1119
# Cutting Dunk Shot                             1041
# Running Jump Shot                              920
# Reverse Layup                                  897
# Turnaround Hook Shot                           890
# Driving Reverse Layup                          842
# Jump Bank Shot                                 735
# Alley Oop Dunk                                 732
# Driving Dunk                                   719
# Running Dunk                                   653
# Driving Hook Shot                              646
# Turnaround Fadeaway Shot                       463
# Turnaround Fadeaway                            445
# Alley Oop Layup                                414
# Driving Floating Bank Jump Shot                408
# Driving Bank Shot                              403
# Putback Dunk                                   323
# Running Pull-Up Jump Shot                      295
# Finger Roll Layup                              289
# Running Finger Roll Layup                      241
# Cutting Finger Roll Layup Shot                 210
# Turnaround Bank Shot                           209
# Pullup Bank Shot                               160
# Tip Dunk Shot                                  152
# 25' 3PT Jump Shot                              146
# Running Reverse Layup                          133
# 24' 3PT Jump Shot                              117
# 3PT Jump Shot                                  103
# 26' 3PT Jump Shot                               97
# ris 26' 3PT Jump Shot                           93
# Hook Bank Shot                                  77
# Running Alley Oop Dunk Shot                     66
# ris 25' 3PT Jump Shot                           65
# Driving Bank Hook Shot                          63
# Fadeaway Bank Shot                              54
# Reverse Dunk                                    50
# ris 24' 3PT Jump Shot                           43
# Turnaround Bank Hook Shot                       42
# 27' 3PT Jump Shot                               41
# Morris 1' Layup                                 39
# Morris 17' Jump Shot                            35
# Morris 15' Jump Shot                            34
# ris 27' 3PT Jump Shot                           33
# Morris 16' Jump Shot                            30
# ris  3PT Jump Shot                              29
# Jr. 20' Jump Shot                               28
# Jr. 1' Driving Layup                            27
# Morris 18' Jump Shot                            26
# Jr. 19' Jump Shot                               25
# Jr. 2' Layup                                    25
# Step Back Bank Jump Shot                        23
# oute 24' 3PT Jump Shot                          23
# Running Alley Oop Layup Shot                    23
# Jr. 1' Layup                                    23
# Jr.  Dunk                                       22
# Morris 19' Jump Shot                            22
# Jr. 2' Driving Layup                            21
# Jr. 18' Jump Shot                               21
# Driving Reverse Dunk Shot                       20
# Jr.  Running Dunk                               19
# Turnaround Fadeaway Bank Jump Shot              19
# oute  3PT Jump Shot                             19
# Jr. 17' Jump Shot                               18
# Morris 20' Jump Shot                            18
# 28' 3PT Jump Shot                               18
# Jr. 1' Running Layup                            17
# Morris 2' Layup                                 17
# Morris  Alley Oop Dunk                          17
# Morris 14' Jump Shot                            17
# Jr.  Driving Dunk                               16
# Morris 12' Jump Shot                            16
# Jr. 2' Running Layup                            15
# Jr. 3' Layup                                    14
# Jr. 15' Jump Shot                               14
# Jr.  Alley Oop Dunk                             14
# Jr. 19' Pullup Jump Shot                        14
# Morris 16' Pullup Jump Shot                     13
# Morris  Dunk                                    13
# Jr. 1' Tip Layup Shot                           13
# Jr. 21' Jump Shot                               12
# Morris 2' Driving Layup                         12
# Morris 5' Jump Shot                             12
# Jr.  Layup                                      12
# Morris 1' Tip Layup Shot                        12
# Jr. 16' Jump Shot                               12
# Jr. 1' Cutting Layup Shot                       11
# Running Reverse Dunk Shot                       11
# Jr. 18' Pullup Jump Shot                        11
# Morris  Layup                                   11
# a Moute 2' Layup                                11
# Jr. 2' Cutting Layup Shot                       11
# Jr. 20' Pullup Jump Shot                        11
# oute 25' 3PT Jump Shot                          10
# Morris 21' Jump Shot                            10
# Morris 6' Jump Shot                             10
# Jr.  Cutting Dunk Shot                          10
# Morris 3' Layup                                 10
# 26' 3PT Pullup Jump Shot                        10
# Morris 7' Jump Shot                              9
# III 2' Layup                                     9
# Morris 18' Pullup Jump Shot                      9
# a Moute 19' Jump Shot                            9
# Morris 10' Jump Shot                             9
# Jr. 6' Jump Shot                                 9
# III 21' Jump Shot                                9
# Jr. 2' Tip Layup Shot                            9
# III 1' Layup                                     9
# Jr. 3' Driving Layup                             9
# Morris 8' Jump Shot                              8
# Jr. 10' Jump Shot                                7
# Jr. 14' Jump Shot                                7
# Morris  Cutting Dunk Shot                        7
# Morris  Driving Dunk                             7
# III 3' Layup                                     7
# Jr. 7' Jump Shot                                 7
# Jr. 17' Pullup Jump Shot                         7
# Jr. 11' Floating Jump Shot                       7
# Jr. 13' Jump Shot                                7
# Morris 4' Jump Shot                              7
# Morris 13' Jump Shot                             7
# Jr. 22' Jump Shot                                7
# 25' 3PT Pullup Jump Shot                         7
# Morris 1' Reverse Layup                          6
# Jr. 1' Driving Finger Roll Layup                 6
# Jr. 7' Floating Jump Shot                        6
# a Moute 1' Reverse Layup                         6
# a Moute 1' Layup                                 6
# 25' 3PT Running Jump Shot                        6
# Morris 11' Jump Shot                             6
# Jr. 3' Cutting Layup Shot                        6
# III  Running Dunk                                6
# Jr. 5' Jump Shot                                 6
# Jr. 9' Jump Shot                                 6
# Morris 2' Tip Layup Shot                         6
# Morris 22' Jump Shot                             6
# Morris 1' Driving Layup                          6
# Jr. 1' Putback Layup                             6
# Morris 14' Fadeaway Jumper                       5
# a Moute  Cutting Dunk Shot                       5
# a Moute 20' Jump Shot                            5
# Morris 9' Jump Shot                              5
# a Moute 2' Reverse Layup                         5
# III 15' Jump Shot                                5
# Jr. 8' Jump Shot                                 5
# ce 24' 3PT Jump Shot                             5
# III 18' Jump Shot                                5
# Morris 19' Pullup Jump Shot                      5
# Jr.  Putback Dunk                                5
# Jr. 3' Jump Shot                                 5
# III 19' Jump Shot                                5
# Morris  Driving Layup                            5
# 24' 3PT Pullup Jump Shot                         5
# ce 25' 3PT Jump Shot                             5
# Morris 20' Pullup Jump Shot                      5
# Morris 15' Pullup Jump Shot                      5
# Morris 21' Pullup Jump Shot                      4
# Morris 14' Turnaround Jump Shot                  4
# ce  3PT Jump Shot                                4
# a Moute  Driving Dunk                            4
# Morris 3' Jump Shot                              4
# Morris 13' Turnaround Jump Shot                  4
# Morris 17' Pullup Jump Shot                      4
# III 22' Jump Shot                                4
# Morris 13' Turnaround Fadeaway                   4
# Morris 14' Pullup Jump Shot                      4
# Morris  Tip Layup Shot                           4
# Jr. 9' Floating Jump Shot                        4
# III 20' Jump Shot                                4
# Morris 16' Fadeaway Jumper                       4
# Jr. 4' Jump Shot                                 4
# Jr. 1' Reverse Layup                             4
# a Moute 21' Jump Shot                            4
# Jr. 12' Pullup Jump Shot                         4
# Jr. 16' Pullup Jump Shot                         4
# Morris 8' Floating Jump Shot                     4
# a Moute 2' Cutting Layup Shot                    4
# Jr. 21' Pullup Jump Shot                         4
# Jr. 2' Reverse Layup                             4
# Jr.  Driving Layup                               4
# a Moute 18' Jump Shot                            4
# 29' 3PT Jump Shot                                4
# oute 26' 3PT Jump Shot                           4
# Driving Jump Shot                                4
# III 3' Cutting Layup Shot                        4
# Morris 8' Turnaround Jump Shot                   4
# III 3' Driving Layup                             4
# ris 28' 3PT Jump Shot                            4
# III 1' Driving Layup                             4
# Jr. 7' Driving Floating Jump Shot                3
# III  Dunk                                        3
# Jr. 2' Putback Layup                             3
# III 17' Pullup Jump Shot                         3
# Jr. 13' Pullup Jump Shot                         3
# 26' 3PT Running Pull-Up Jump Shot                3
# Jr. 12' Jump Shot                                3
# III 6' Jump Shot                                 3
# Jr.  Running Layup                               3
# Morris 13' Fadeaway Jumper                       3
# III 17' Jump Shot                                3
# a Moute 2' Driving Layup                         3
# Jr. 3' Putback Layup                             3
# Morris 12' Fadeaway Jumper                       3
# 3PT Step Back Jump Shot                          3
# Jr. 11' Jump Shot                                3
# Jr. 6' Floating Jump Shot                        3
# Morris 14' Step Back Jump Shot                   3
# a Moute 2' Driving Reverse Layup                 3
# Jr. 15' Step Back Jump Shot                      3
# III 19' Pullup Jump Shot                         3
# III 2' Driving Layup                             3
# a Moute 3' Layup                                 3
# Morris 5' Turnaround Jump Shot                   3
# Jr. 3' Running Jump Shot                         3
# Morris 2' Driving Reverse Layup                  3
# Morris 13' Step Back Jump Shot                   3
# Morris 16' Turnaround Jump Shot                  3
# Morris 10' Turnaround Jump Shot                  3
# Jr. 5' Driving Floating Jump Shot                3
# a Moute 16' Jump Shot                            3
# a Moute  Dunk                                    3
# Jr. 14' Fadeaway Jumper                          3
# Jr. 10' Floating Jump Shot                       3
# Jr. 4' Floating Jump Shot                        3
# Morris 1' Cutting Layup Shot                     3
# Morris 9' Turnaround Jump Shot                   3
# Morris 19' Step Back Jump Shot                   3
# III 14' Jump Shot                                3
# Jr. 15' Pullup Jump Shot                         3
# Jr. 9' Driving Floating Jump Shot                3
# III 11' Jump Shot                                3
# Morris  Driving Reverse Layup                    3
# Jr. 8' Floating Jump Shot                        2
# III 1' Cutting Layup Shot                        2
# a Moute 21' Running Pull-Up Jump Shot            2
# 27' 3PT Pullup Jump Shot                         2
# III 1' Tip Layup Shot                            2
# III 20' Step Back Jump Shot                      2
# Morris 11' Turnaround Jump Shot                  2
# 30' 3PT Jump Shot                                2
# Jr. 15' Fadeaway Jumper                          2
# III 2' Running Layup                             2
# Jr. 8' Pullup Bank Shot                          2
# Jr. 2' Alley Oop Layup                           2
# ce 26' 3PT Jump Shot                             2
# Morris 19' Fadeaway Jumper                       2
# 25' 3PT Running Pull-Up Jump Shot                2
# Jr. 9' Turnaround Jump Shot                      2
# Morris 17' Step Back Jump Shot                   2
# Jr. 3' Tip Layup Shot                            2
# III  Cutting Dunk Shot                           2
# Morris 10' Step Back Jump Shot                   2
# Morris 6' Hook Shot                              2
# Jr.  Tip Layup Shot                              2
# 26' 3PT Running Jump Shot                        2
# Jr. 6' Driving Hook Shot                         2
# Morris 8' Fadeaway Jumper                        2
# Peace 19' Jump Shot                              2
# Morris 16' Turnaround Fadeaway Shot              2
# Peace 21' Pullup Jump Shot                       2
# Jr. 1' Cutting Finger Roll Layup Shot            2
# Peace 2' Driving Layup                           2
# Morris 6' Turnaround Jump Shot                   2
# Jr. 10' Driving Floating Jump Shot               2
# Morris 13' Pullup Jump Shot                      2
# a Moute 2' Running Layup                         2
# Morris 18' Fadeaway Jumper                       2
# Jr.  Putback Layup                               2
# IV 2' Running Layup                              2
# Morris 21' Step Back Jump Shot                   2
# III 23' Jump Shot                                2
# Morris 9' Pullup Jump Shot                       2
# III 2' Driving Reverse Layup                     2
# Jr. 3' Driving Bank Shot                         2
# a Moute 1' Driving Reverse Layup                 2
# Morris 3' Tip Layup Shot                         2
# Morris 20' Step Back Jump Shot                   2
# III  Layup                                       2
# Jr.  Running Finger Roll Layup                   2
# Morris 17' Turnaround Jump Shot                  2
# Morris 23' Jump Shot                             2
# Morris 3' Driving Layup                          2
# Morris 6' Driving Bank Shot                      2
# Morris 16' Step Back Jump Shot                   2
# Morris 1' Putback Layup                          2
# Morris  Putback Dunk                             2
# Jr. 7' Turnaround Hook Shot                      2
# Morris 2' Putback Layup                          2
# Morris 18' Step Back Jump Shot                   2
# a Moute 2' Driving Finger Roll Layup             2
# ris 25' 3PT Pullup Jump Shot                     2
# Jr. 3' Reverse Layup                             2
# Morris 6' Fadeaway Jumper                        2
# Jr. 6' Running Jump Shot                         2
# a Moute 1' Driving Layup                         2
# Morris 10' Pullup Jump Shot                      2
# Morris  Putback Layup                            2
# Jr. 11' Turnaround Jump Shot                     2
# Morris 2' Cutting Layup Shot                     2
# a Moute 4' Jump Shot                             2
# Morris 8' Pullup Jump Shot                       2
# Morris 7' Turnaround Jump Shot                   2
# Jr. 9' Hook Shot                                 2
# Morris 9' Hook Shot                              2
# Jr. 12' Turnaround Jump Shot                     2
# 25' 3PT Step Back Jump Shot                      2
# Morris 7' Running Jump Shot                      2
# Jr. 4' Layup                                     2
# Morris  Driving Hook Shot                        1
# Jr. 4' Tip Layup Shot                            1
# ris 29' 3PT Jump Shot                            1
# Morris 1' Alley Oop Layup                        1
# 40' 3PT Running Pull-Up Jump Shot                1
# Morris 3' Putback Layup                          1
# a Moute 21' Pullup Jump Shot                     1
# III 2' Cutting Layup Shot                        1
# Jr. 5' Jump Bank Shot                            1
# Jr. 20' Pullup Bank Shot                         1
# Peace  Layup                                     1
# Morris 15' Step Back Jump Shot                   1
# 32' 3PT Running Pull-Up Jump Shot                1
# Jr. 8' Driving Bank Shot                         1
# Jr. 8' Turnaround Jump Shot                      1
# Morris 13' Turnaround Fadeaway Shot              1
# Peace 18' Jump Shot                              1
# IV 6' Floating Jump Shot                         1
# ris 27' 3PT Step Back Jump Shot                  1
# Morris 11' Floating Jump Shot                    1
# III 3' Running Dunk                              1
# Morris 2' Cutting Finger Roll Layup Shot         1
# Jr.  Cutting Layup Shot                          1
# 29' 3PT Pullup Jump Shot                         1
# III 6' Hook Bank Shot                            1
# Morris 7' Turnaround Hook Shot                   1
# Morris 7' Tip Layup Shot                         1
# Peace 21' Jump Shot                              1
# Jr. 2' Driving Bank Shot                         1
# Jr. 4' Jump Bank Shot                            1
# a Moute  Driving Reverse Layup                   1
# Jr. 16' Step Back Jump Shot                      1
# ris 26' 3PT Pullup Jump Shot                     1
# a Moute 8' Hook Shot                             1
# III 16' Fadeaway Jumper                          1
# Jr. 1' Finger Roll Layup                         1
# III 7' Jump Shot                                 1
# 27' 3PT Running Jump Shot                        1
# Jr. 5' Driving Bank Shot                         1
# Morris 11' Turnaround Bank Hook Shot             1
# Jr. 19' Running Jump Shot                        1
# Morris 22' Pullup Jump Shot                      1
# 54' 3PT Running Pull-Up Jump Shot                1
# Peace 17' Pullup Jump Shot                       1
# a Moute 22' Jump Shot                            1
# III  Tip Layup Shot                              1
# a Moute 15' Pullup Jump Shot                     1
# Jr. 19' Step Back Jump Shot                      1
# Morris 8' Driving Floating Bank Jump Shot        1
# a Moute 17' Jump Shot                            1
# ris 79' 3PT Jump Shot                            1
# Morris 1' Driving Finger Roll Layup              1
# Jr. 9' Running Pull-Up Jump Shot                 1
# Jr. 14' Turnaround Fadeaway                      1
# Morris 4' Turnaround Jump Shot                   1
# Jr. 12' Fadeaway Jumper                          1
# Jr.  Tip Dunk Shot                               1
# III 5' Jump Shot                                 1
# Jr. 18' Step Back Jump Shot                      1
# II 4' Driving Finger Roll Layup                  1
# III 8' Running Jump Shot                         1
# Jr. 4' Driving Floating Jump Shot                1
# Morris 1' Running Layup                          1
# Morris 4' Driving Bank Shot                      1
# IV 2' Cutting Layup Shot                         1
# III 7' Hook Shot                                 1
# Morris 9' Driving Bank Shot                      1
# Jr. 2' Cutting Finger Roll Layup Shot            1
# Morris 6' Driving Hook Shot                      1
# Morris 2' Reverse Layup                          1
# Jr. 22' Fadeaway Jumper                          1
# Jr. 16' Turnaround Jump Shot                     1
# Jr. 23' Jump Shot                                1
# III 10' Floating Jump Shot                       1
# a Moute 5' Jump Shot                             1
# Morris 6' Driving Floating Bank Jump Shot        1
# III 10' Driving Bank Shot                        1
# Morris 12' Step Back Jump Shot                   1
# III 15' Step Back Jump Shot                      1
# Jones, Jr.  Cutting Dunk Shot                    1
# III 1' Putback Layup                             1
# 69' 3PT Jump Shot                                1
# Jr. 15' Driving Floating Jump Shot               1
# Morris 17' Fadeaway Jumper                       1
# Jr. 20' Turnaround Jump Shot                     1
# 31' 3PT Jump Shot                                1
# Morris 9' Fadeaway Jumper                        1
# 33' 3PT Jump Shot                                1
# Jr. 4' Running Layup                             1
# Jr. 18' Pullup Bank Shot                         1
# III 1' Running Layup                             1
# Morris 7' Jump Bank Shot                         1
# a Moute 17' Running Pull-Up Jump Shot            1
# III 18' Step Back Jump Shot                      1
# Jr. 7' Driving Hook Shot                         1
# Jr. 6' Hook Shot                                 1
# Jr. 3' Driving Floating Jump Shot                1
# a Moute 17' Pullup Jump Shot                     1
# 66' 3PT Running Jump Shot                        1
# III 9' Jump Shot                                 1
# Morris 11' Fadeaway Jumper                       1
# IV 1' Cutting Layup Shot                         1
# Morris 5' Running Jump Shot                      1
# Morris 3' Driving Hook Shot                      1
# a Moute 3' Driving Floating Jump Shot            1
# III 1' Driving Reverse Layup                     1
# Jr. 13' Driving Floating Jump Shot               1
# Jr. 3' Driving Floating Bank Jump Shot           1
# Morris 2' Jump Shot                              1
# a Moute 3' Cutting Layup Shot                    1
# Morris 9' Running Jump Shot                      1
# Jr. 17' Step Back Jump Shot                      1
# III 9' Turnaround Jump Shot                      1
# Jr. 3' Cutting Finger Roll Layup Shot            1
# III 8' Turnaround Jump Shot                      1
# a Moute  Reverse Layup                           1
# Jr. 12' Running Pull-Up Jump Shot                1
# Jr. 4' Driving Layup                             1
# Jr. 10' Turnaround Fadeaway                      1
# Morris 11' Pullup Jump Shot                      1
# Jr. 13' Step Back Jump Shot                      1
# Jr. 4' Pullup Jump Shot                          1
# III 2' Putback Layup                             1
# Morris 15' Turnaround Jump Shot                  1
# a Moute 1' Running Layup                         1
# II 15' Pullup Jump Shot                          1
# a Moute  Running Dunk                            1
# III 1' Finger Roll Layup                         1
# Morris 12' Turnaround Fadeaway                   1
# Morris 1' Driving Reverse Layup                  1
# 26' 3PT Pullup Bank Shot                         1
# Morris 5' Driving Hook Shot                      1
# III 3' Driving Bank Shot                         1
# 24' 3PT Running Pull-Up Jump Shot                1
# III 2' Reverse Layup                             1
# ce 64' 3PT Jump Shot                             1
# Jr. 12' Turnaround Hook Shot                     1
# Jr. 7' Pullup Jump Shot                          1
# III  Putback Dunk                                1
# Morris 4' Driving Hook Shot                      1
# Jr. 15' Turnaround Bank Hook Shot                1
# 28' 3PT Pullup Jump Shot                         1
# 34' 3PT Jump Shot                                1
# Jr. 17' Fadeaway Jumper                          1
# IV 3' Tip Layup Shot                             1
# ris 24' 3PT Running Jump Shot                    1
# Jr. 3' Running Layup                             1
# III  Alley Oop Dunk                              1
# Peace 8' Fadeaway Bank Shot                      1
# Jr. 13' Fadeaway Jumper                          1
# a Moute 2' Tip Layup Shot                        1
# Jr. 3' Cutting Dunk Shot                         1
# 37' 3PT Running Jump Shot                        1
# III  Running Layup                               1
# Peace 20' Step Back Jump Shot                    1
# Jr.  Finger Roll Layup                           1
# Jr. 6' Driving Floating Jump Shot                1
# Morris 7' Hook Shot                              1
# Jr. 14' Floating Jump Shot                       1
# Morris 14' Turnaround Fadeaway Shot              1
# Jr.  Driving Finger Roll Layup                   1
# III 14' Pullup Jump Shot                         1
# Jr. 16' Pullup Bank Shot                         1
# Morris 12' Turnaround Jump Shot                  1
# 49' 3PT Running Pull-Up Jump Shot                1
# Jr. 15' Floating Jump Shot                       1
# III  Driving Finger Roll Layup                   1
# Morris 6' Driving Floating Jump Shot             1
# Jr. 7' Driving Bank Hook Shot                    1
# III 3' Dunk                                      1
# Jr. 8' Pullup Jump Shot                          1
# a Moute 4' Hook Bank Shot                        1
# Jr. 21' Fadeaway Jumper                          1
# Jr. 1' Running Dunk                              1
# a Moute 3' Running Layup                         1
# ris 26' 3PT Running Jump Shot                    1
# Morris 16' Turnaround Fadeaway                   1
# 24' 3PT Step Back Jump Shot                      1
# III 4' Driving Layup                             1
# Morris 4' Turnaround Hook Shot                   1
# Jr. 10' Turnaround Hook Shot                     1
# Jr. 10' Hook Shot                                1
# III 10' Jump Shot                                1
# Peace 17' Fadeaway Jumper                        1
# Morris 7' Fadeaway Jumper                        1
# Jr. 10' Running Jump Shot                        1
# Morris 6' Floating Jump Shot                     1
# 27' 3PT Running Pull-Up Jump Shot                1
# IV 11' Jump Shot                                 1
# III 1' Alley Oop Layup                           1
# III 3' Jump Shot                                 1
# Morris 14' Pullup Bank Shot                      1
# Morris 8' Turnaround Hook Shot                   1
# a Moute 3' Running Reverse Layup                 1
# II 2' Dunk                                       1
# Running Hook Shot                                1
# IV 3' Running Layup                              1
# oute 37' 3PT Jump Shot                           1
# 41' 3PT Jump Shot                                1
# a Moute 2' Running Reverse Layup                 1
# III 16' Pullup Jump Shot                         1
# Jr. 15' Turnaround Hook Shot                     1
# Jr.  Driving Reverse Dunk Shot                   1
# IV  Cutting Layup Shot                           1
# 3PT Floating Jump Shot                           1
# a Moute 3' Tip Layup Shot                        1
# Morris 3' Alley Oop Layup                        1
# Peace 6' Jump Shot                               1
# 29' 3PT Jump Bank Shot                           1
# a Moute 3' Reverse Layup                         1
# II  Driving Dunk                                 1
# Morris 5' Fadeaway Jumper                        1
# III  Reverse Layup                               1
# Morris 1' Finger Roll Layup                      1
# III 10' Turnaround Fadeaway                      1
# Jr. 9' Pullup Jump Shot                          1
# III 2' Cutting Dunk Shot                         1
# III 6' Driving Floating Jump Shot                1
# III 5' Layup                                     1
# Jr. 3' Turnaround Jump Shot                      1
# ce 27' 3PT Jump Shot                             1
# Jr. 20' Fadeaway Jumper                          1
# Jr. 8' Hook Shot                                 1
# Jones, Jr. 1' Tip Layup Shot                     1
# Morris  Running Alley Oop Dunk Shot              1
# Jr. 12' Step Back Jump Shot                      1
# Morris 9' Turnaround Fadeaway                    1
# Jr. 2' Driving Finger Roll Layup                 1
# Jr. 2' Turnaround Bank Shot                      1
# a Moute 18' Pullup Jump Shot                     1
# 48' 3PT Jump Shot                                1
# Morris 7' Driving Floating Jump Shot             1
# III 16' Jump Shot                                1
# 32' 3PT Pullup Bank Shot                         1
# Jr. 5' Driving Hook Shot                         1
# Morris 3' Alley Oop Dunk                         1
# Morris 14' Driving Floating Jump Shot            1
# III 13' Jump Shot                                1
# IV 1' Tip Layup Shot                             1
# III 5' Floating Jump Shot                        1
# Jr. 6' Turnaround Jump Shot                      1
# Morris 5' Floating Jump Shot                     1
# Jr. 2' Running Dunk                              1
# Jr. 16' Jump Bank Shot                           1
# Morris 2' Alley Oop Layup                        1
# Jr. 3' Alley Oop Layup                           1
# II 2' Driving Finger Roll Layup                  1
# Jr. 15' Running Pull-Up Jump Shot                1
# a Moute  Cutting Layup Shot                      1
# IV 2' Layup                                      1
# ce 31' 3PT Jump Shot                             1
# a Moute 3' Finger Roll Layup                     1
# IV 9' Jump Shot                                  1
# Jr.  Running Alley Oop Dunk Shot                 1
# Morris 4' Driving Layup                          1
# III 10' Turnaround Jump Shot                     1
# III 1' Cutting Finger Roll Layup Shot            1
# III 13' Floating Jump Shot                       1
# II 1' Layup                                      1
# ce 25' 3PT Pullup Jump Shot                      1
# Peace 10' Fadeaway Jumper                        1
# Peace 1' Driving Layup                           1
# Morris 16' Running Jump Shot                     1
# III 4' Turnaround Hook Shot                      1
# II 3' Driving Layup                              1
# Jr. 1' Running Reverse Layup                     1
# III 7' Driving Floating Jump Shot                1
# Peace 20' Jump Shot                              1
# Jr. 4' Hook Shot                                 1
# a Moute 22' Step Back Jump Shot                  1
# III 13' Fadeaway Jumper                          1
# oute 45' 3PT Jump Shot                           1
# III 6' Floating Jump Shot                        1
# Jr.  Alley Oop Layup                             1
# IV 2' Driving Layup                              1
# Jr. 12' Floating Jump Shot                       1
# Morris  Running Dunk                             1
# Jr. 4' Driving Bank Shot                         1
# III 21' Pullup Jump Shot                         1
# a Moute 20' Step Back Jump Shot                  1
# Jr. 14' Turnaround Jump Shot                     1
# III 8' Driving Floating Bank Jump Shot           1
# Jr. 1' Driving Reverse Layup                     1
# Jones, Jr.  Putback Dunk                         1
# III 16' Step Back Jump Shot                      1
# IV 3' Driving Finger Roll Layup                  1
# Peace 16' Pullup Jump Shot                       1
# III 12' Turnaround Jump Shot                     1
# Peace 14' Step Back Jump Shot                    1
# Name: shot type, dtype: int64

# %%
def clean(shottype):
    shot_type = shottype.split("'")[-1]
    shot_type = shot_type.split(".")[-1]
    shot_type = shot_type.replace(" ","").lower()
    shot_type = shot_type.replace("morris","").replace("iii","").replace("amoute","").replace("iv","").replace("ii","")

    if "bank" in shot_type:
        return "bankshot"
    elif "putback" in shot_type:
        return "putback"
    elif "3pt" in shot_type:
        return "3ptshot"
    elif "cutting" in shot_type:
        return "cutting"
    elif "alleyoop" in shot_type:
        return "alleyoop"
    else:
        return shot_type
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df["shot type"].apply(clean).value_counts())
# Out:
# jumpshot                  47612
# layup                      8142
# pullupjumpshot             7511
# dringlayup                 6792
# cutting                    3262
# floatingjumpshot           2317
# stepbackjumpshot           2304
# bankshot                   2229
# hookshot                   2098
# tiplayupshot               2089
# runninglayup               1874
# turnaroundjumpshot         1672
# dringfloatingjumpshot      1613
# putback                    1487
# dunk                       1428
# fadeawayjumper             1410
# alleyoop                   1278
# dringfingerrolllayup       1134
# 3ptshot                     942
# runningjumpshot             933
# reverselayup                929
# turnaroundhookshot          899
# dringreverselayup           859
# dringdunk                   747
# runningdunk                 683
# dringhookshot               655
# turnaroundfadeawayshot      467
# turnaroundfadeaway          455
# runningpull-upjumpshot      301
# fingerrolllayup             294
# runningfingerrolllayup      243
# tipdunkshot                 153
# runningreverselayup         136
# reversedunk                  50
# dringreversedunkshot         21
# runningreversedunkshot       11
# dringjumpshot                 4
# runninghookshot               1
# peacelayup                    1
# Name: shot type, dtype: int64

# %% [markdown]
# ## 전처리 최종

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer


df = pd.read_csv("NBA_TRAIN.csv")
df_test = pd.read_csv("NBA_TEST.csv")

def is_topplayer(x):
    if x in top_players:
        return 1
    else :
        return 0
def is_guaranteed_players(x):
    if x in guaranteed_players:
        return 1
    else :
        return 0
def get_distance(x, y):
    new_x = min(abs((933)-x),x)
    new_y = abs((500/2)-y)
    return (new_x**2+new_y**2)**0.5
def time_to_sec(time):
    m,s = time.split(":")
    return int(m)*60+int(s)

def clean(shottype):
    shot_type = shottype.split("'")[-1]
    shot_type = shot_type.split(".")[-1]
    shot_type = shot_type.replace(" ","").lower()
    shot_type = shot_type.replace("morris","").replace("iii","").replace("amoute","").replace("iv","").replace("ii","")

    if "bank" in shot_type:
        return "bankshot"
    elif "putback" in shot_type:
        return "putback"
    elif "3pt" in shot_type:
        return "3ptshot"
    elif "cutting" in shot_type:
        return "cutting"
    elif "alleyoop" in shot_type:
        return "alleyoop"
    else:
        return shot_type
    
    
    return shot_type



enc = LabelEncoder()
X = enc.fit_transform(df["home team"])
df["home team"] = X
X = enc.transform(df_test["home team"])
df_test["home team"] = X
X = enc.transform(df["away team"])
df["away team"] = X
X = enc.transform(df_test["away team"])
df_test["away team"] = X
enc2 = LabelEncoder()
df["shot type"] = df["shot type"].apply(clean)
X = enc2.fit_transform(df["shot type"])
df["shot type"] = X
df_test["shot type"] = df_test["shot type"].apply(clean)
X = enc2.transform(df_test["shot type"])
df_test["shot type"] = X

def preprocesing(df):
    median = df["time from last shot"].median()
    df["time from last shot"].fillna(median, inplace=True)
    median = df["location x"].median()
    df["location x"].fillna(median, inplace=True)
    median = df["location y"].median()
    df["location y"].fillna(median, inplace=True)
    
    df["distance"] = df.apply(lambda x: get_distance(x["location x"], x["location y"]), axis=1)

    df["is_topplayer"] = df["shoot player"].apply(is_topplayer)
    df["is_guaranteed_players"] = df["shoot player"].apply(is_topplayer)


    df.loc[df['home game']!="Yes","HG"] = 0
    df.loc[df['home game']=="Yes","HG"] = 1
    df.loc[df['self previous shot']!="SCORED","SPS"] = 0
    df.loc[df['self previous shot']=="SCORED","SPS"] = 1
    df.loc[df['opponent previous shot']!="SCORED","OPS"] = 0
    df.loc[df['opponent previous shot']=="SCORED","OPS"] = 1
    

    try:
        df.loc[df['current shot outcome']!="SCORED","CSO"] = 0
        df.loc[df['current shot outcome']=="SCORED","CSO"] = 1
        df.drop(columns=["current shot outcome"], inplace=True)
    except:
        pass
    
    try:
        df.drop(columns=["id"], inplace=True)
    except:
        pass



    df['day'] = pd.to_datetime(df['date']).dt.dayofweek 
    df.drop(columns="date",axis=1, inplace=True)
    df.drop(columns="shoot player",axis=1, inplace=True)
    df['seconds'] = df['time'].apply(time_to_sec)
    df.drop(columns=["time"], inplace=True)
    
    

    df.drop(columns=["self previous shot", "opponent previous shot"], inplace=True)
    df.drop(columns=["home game"], inplace=True)
    df = pd.get_dummies(df)
    return df
new_df_test = preprocesing(df_test)
new_df = preprocesing(df)

# %%
new_df.head()
# Out:
#    location x  home team  shot type  points  away team  location y  \
# 0       676.0         18         17       2          4       225.0
# 1        59.0         13         18       2          6       230.0
# 2        50.0          2         18       2          3       269.0
# 3       194.0         13         20       2         24       357.0
# 4        35.0         14         17       2         19       449.0
#
#    time from last shot  quarter    distance  is_topplayer  ...  CSO  day  \
# 0                  9.0        1  258.213090             0  ...  1.0    6
# 1                 45.0        1   62.297673             0  ...  0.0    3
# 2                 46.0        3   53.488316             0  ...  1.0    4
# 3                 31.0        4  221.551348             0  ...  1.0    1
# 4                 27.0        3  202.054448             0  ...  0.0    4
#
#    seconds  player position_C  player position_F  player position_G  \
# 0      648                  0                  0                  0
# 1      110                  0                  0                  0
# 2      246                  1                  0                  0
# 3       13                  0                  0                  0
# 4      698                  0                  0                  0
#
#    player position_PF  player position_PG  player position_SF  \
# 0                   1                   0                   0
# 1                   0                   1                   0
# 2                   0                   0                   0
# 3                   0                   0                   0
# 4                   1                   0                   0
#
#    player position_SG
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   0
#
# [5 rows x 24 columns]

# %%
new_df.columns
# Out:
# Index(['location x', 'home team', 'shot type', 'points', 'away team',
#        'location y', 'time from last shot', 'quarter', 'distance',
#        'is_topplayer', 'is_guaranteed_players', 'HG', 'SPS', 'OPS', 'CSO',
#        'day', 'seconds', 'player position_C', 'player position_F',
#        'player position_G', 'player position_PF', 'player position_PG',
#        'player position_SF', 'player position_SG'],
#       dtype='object')

# %%
train_y = new_df['CSO']
train_X = new_df.drop("CSO", axis=1) # 훈련 세트를 위해 레이블 삭제
test_X = new_df_test

# %%
train_X.shape
# Out:
# (105036, 23)

# %%
test_X.shape
# Out:
# (105036, 23)

# %%
new_df.corr()["CSO"].sort_values()
# Out:
# distance                -0.198998
# points                  -0.137947
# shot type               -0.082057
# time from last shot     -0.043894
# player position_SG      -0.021611
# player position_G       -0.021242
# player position_PG      -0.017733
# quarter                 -0.016209
# player position_SF      -0.014868
# OPS                     -0.014041
# seconds                 -0.014024
# SPS                     -0.008499
# player position_F       -0.005570
# location x              -0.001357
# day                     -0.000700
# home team                0.001715
# away team                0.001719
# location y               0.002802
# is_topplayer             0.008259
# is_guaranteed_players    0.008259
# HG                       0.008688
# player position_PF       0.014180
# player position_C        0.060157
# CSO                      1.000000
# Name: CSO, dtype: float64

# %% [markdown]
# ## 4. 정규화로 마무리

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# %% [markdown]
# ## 모든 Classifier 한번 테스트

# %%
from sklearn.utils import all_estimators

estimators = all_estimators(type_filter='classifier')

all_regs = []
for name, RegressorClass in estimators:
    
    try:
        reg = RegressorClass()
        all_regs.append(reg)
        print(name)
    except:
        pass
# Out:
# AdaBoostClassifier
# BaggingClassifier
# BernoulliNB
# CalibratedClassifierCV
# CategoricalNB
# ComplementNB
# DecisionTreeClassifier
# DummyClassifier
# ExtraTreeClassifier
# ExtraTreesClassifier
# GaussianNB
# GaussianProcessClassifier
# GradientBoostingClassifier
# HistGradientBoostingClassifier
# KNeighborsClassifier
# LabelPropagation
# LabelSpreading
# LinearDiscriminantAnalysis
# LinearSVC
# LogisticRegression
# LogisticRegressionCV
# MLPClassifier
# MultinomialNB
# NearestCentroid
# NuSVC
# PassiveAggressiveClassifier
# Perceptron
# QuadraticDiscriminantAnalysis
# RadiusNeighborsClassifier
# RandomForestClassifier
# RidgeClassifier
# RidgeClassifierCV
# SGDClassifier
# SVC

# %% [markdown]
# ## 베이스라인 모델로 검증
# - 전처리 또는 feature engineering을 변경하면서 이구간에서 최대한 성능 향상

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import HistGradientBoostingClassifier

rfc=RandomForestClassifier(random_state=42)

scores = cross_val_score(rfc, train_X, train_y, cv=5)
print(scores)
# Out:
# [0.64975248 0.65135431 0.64159566 0.64559433 0.64435664]

# %% [markdown]
# ## 여러 Classifier 검증

# %%
results = []
SUPER_SLOW_REGRESSION = ["SVC","NuSVC","GaussianProcessClassifier","LabelPropagation","LabelSpreading"]
for reg in all_regs:
    reg_name = reg.__class__.__name__ 
    if reg_name not in SUPER_SLOW_REGRESSION:
        try:

            scores = cross_val_score(reg, train_X, train_y,  cv=5)

            if not scores.mean():
                break
            print("{}: Score {}".format(reg.__class__.__name__, scores.mean()))
            result = {
                "Name":reg.__class__.__name__, 
                "Score":scores.mean()
            }
            results.append(result)
        except Exception as e:
            print(e)
            pass
# Out:
# AdaBoostClassifier: Score 0.645331062985533
# BaggingClassifier: Score 0.6209966183433362
# BernoulliNB: Score 0.5623691025850702
# CalibratedClassifierCV: Score 0.5988898565926107
# index 1 is out of bounds for axis 1 with size 1
# ComplementNB: Score 0.5610076416699457
# DecisionTreeClassifier: Score 0.5712137054304351
# DummyClassifier: Score 0.5051410863263184
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/dummy.py:131: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   warnings.warn("The default value of strategy will change from "
# ExtraTreeClassifier: Score 0.5491546370446061
# ExtraTreesClassifier: Score 0.6291747154894257
# GaussianNB: Score 0.5865703004703289
# GradientBoostingClassifier: Score 0.6521953839707658
# HistGradientBoostingClassifier: Score 0.6592691720900635
# KNeighborsClassifier: Score 0.5541718617458635
# LinearDiscriminantAnalysis: Score 0.5987184896769078
# LinearSVC: Score 0.5987184883173349
# LogisticRegression: Score 0.5988803368630142
# LogisticRegressionCV: Score 0.599870492521787
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier: Score 0.6332399762948491
# MultinomialNB: Score 0.5698998408973385
# NearestCentroid: Score 0.5503160617298313
# PassiveAggressiveClassifier: Score 0.5156904046346427
# Perceptron: Score 0.5249723009676788
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages/sklearn/discriminant_analysis.py:715: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# QuadraticDiscriminantAnalysis: Score 0.5241537193328841
# No neighbors found for test samples array([15376]), you can try using larger radius, giving a label for outliers, or considering removing them from your dataset.
# RandomForestClassifier: Score 0.644788394892197
# RidgeClassifier: Score 0.5987470502252703
# RidgeClassifierCV: Score 0.5987470502252703
# SGDClassifier: Score 0.5951387754149045

# %% [markdown]
# ## 가장 잘 나온 모델 튜닝
# - HistGradientBoostingClassifier

# %%
param_grid = { 
    'learning_rate':(0.1,0.01,0.005),
    'max_iter':(1000,2000),
    'max_leaf_nodes':(None,50,60,70),
    'tol':(1e-6,1e-7,1e-8)
}


#instantiate the gridsearch
hbc = HistGradientBoostingClassifier()
hgb_grid = GridSearchCV(estimator =hbc, param_grid= param_grid, n_jobs=-1, 
 cv=5, scoring='accuracy',
 verbose=3, refit=True)
#fit on the grid 
hgb_grid.fit(train_X, train_y)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed:  8.1min

# %%
# Print the best parameters found
print(hgb_grid.best_params_)
# Print the best scores found
print(hgb_grid.best_score_)

# %% [markdown]
# ## 최종 예측

# %%
hbc = HistGradientBoostingClassifier(learning_rate= 0.01, max_iter=1000, max_leaf_nodes=50, tol=1e-07, random_state=42)
hbc.fit(train_X, train_y)

# %%
predicts = hbc.predict(test_X)

# %%
predicts

# %%
result = pd.DataFrame(predicts, columns=["current shot outcome"])

# %%
result["id"] = result.index
result

# %%
result["current shot outcome"].value_counts()

# %%
result.loc[result["current shot outcome"]==1,"current shot outcome"]= "SCORED"

# %%
result.loc[result["current shot outcome"]==0,"current shot outcome"]= "MISSED"

# %%
result

# %%
result = result[['id',"current shot outcome"]]
result

# %%
result.to_csv("submission.csv",index=False)
