# %% [markdown]
# # BIG DATA ANALYTICS: Map using folium
# ---

# %%
import sys
# !{sys.executable} -m pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.11.0-py2.py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 700 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.2)
# Requirement already satisfied: requests in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/jungwons/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (3.0.4)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.1 folium-0.11.0

# %%
import pandas as pd
import folium

# %%
df = pd.read_csv("data/covid.csv")

# %%
df
# Out:
#       지역    일자                 지명                주소  \
# 0     경북   4/9               인정식당  경북예천군예천읍동본리558-1
# 1     경북   4/9              예천권병원  경북예천군예천읍동본리460-2
# 2     인천  4/16             인천국제공항       인천중구운서동2851
# 3     인천  4/16  코로나19미추홀구보건소선별진료소    인천미추홀구도화동357-1
# 4     인천  4/17           인천광역시의료원      인천동구송림동318-1
# ...   ..   ...                ...               ...
# 1532  대전  6/17          TR이노베이션침향      대전중구오류동154-4
# 1533  대전  6/15                그곳에    대전유성구갑동387-131
# 1534  대전  6/17        계룡산온천사우나찜질방    충남공주시반포면학봉리923
# 1535  서울  6/16         인제대학교서울백병원        서울중구저동2가85
# 1536  경기  6/18   코로나19남양주보건소선별진료소   경기남양주시다산동3159-7
#
#                                          좌표
# 0     36.656190351426105,128.45736624511812
# 1       36.65741494944681,128.4589058076981
# 2      37.44945028134419,126.45042670237001
# 3      37.46109730656191,126.67744386263398
# 4         37.4788434212658,126.668610185659
# ...                                     ...
# 1532   36.32222356176526,127.41040828054733
# 1533   36.36275991438219,127.29586937109401
# 1534    36.3655881150026,127.25253998879701
# 1535  37.565050643045105,126.98883967451602
# 1536   37.610500142345956,127.1711727565189
#
# [1537 rows x 5 columns]

# %%
m = folium.Map(location=[35.4, 127], zoom_start=7)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(location=[35.4, 127], zoom_start=7, tiles='Stamen Toner')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(800):
    name = df.loc[i, '지명']
    try:
        lat, lng = df.loc[i, '좌표'].split(",")
        folium.Circle( location = (lat,lng), tooltip = name, radius = 200 ).add_to(map_osm)
    except:
        pass
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
